# %%
from context import imagearchive

# %%
import imagearchive.config
help(imagearchive.config)
# Out:
# Help on module imagearchive.config in imagearchive:
#
# NAME
#     imagearchive.config - Configuration for
#
# DESCRIPTION
#     1. a SQLAlchemy database url and session
#     2. the Ingest, Data, and Output Directory classes and methods
#
# CLASSES
#     builtins.object
#         Directory
#             DataDirectory
#             IngestDirectory
#             OutputDirectory
#
#     class DataDirectory(Directory)
#      |  DataDirectory(**kwargs)
#      |
#      |  Images are to be output from a DataDirectory
#      |
#      |  Method resolution order:
#      |      DataDirectory
#      |      Directory
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, **kwargs)
#      |      Initializes the Directory, creating one if it doesn't exist.
#      |
#      |      :abspath: str, absolute path to directory
#      |
#      |  ----------------------------------------------------------------------
# ...

# %%
import imagearchive.utils
help(imagearchive.utils)
# Out:
# Help on module imagearchive.utils in imagearchive:
#
# NAME
#     imagearchive.utils
#
# DESCRIPTION
#     Utility functions for methods on the Directory classes, esp. for the image
#     ingestion workflow. Defines `get_normalized_catalog`, which implicitly
#     assumes that CSV or TSV metadata "tagfiles" are embedded in the directory tree
#     containing images to be ingest.
#
# FUNCTIONS
#     assign_uuid(filepath, overwrite=False)
#         Reads EXIF:ImageUniqueID tag for valid uuid. If no uuid exists, write mint_uuid() to EXIF:ImageUniqueID tag.
#
#     flatten_list(nested_list)
#
#     get_fixed_seq()
#         Declares/updates global fixed_seq, which seeds mind_uuid().
#
#     get_normalized_catalog(data_dir, overwrite=False)
#         Catalogs the files and directories below the data_dir (relative path),
#         given '.csv' or '.tsv' metadata (TODO or '.json') in the directory tree.
#
#         :pool_metadata: "metadata gathering" function defined below.
#
# ...

# %%
import imagearchive.schema
help(imagearchive.schema)
# Out:
# Help on module imagearchive.schema in imagearchive:
#
# NAME
#     imagearchive.schema
#
# DESCRIPTION
#     Defines classes mapped to relational database tables, using SQLAlchemy's
#     Declarative system. docs.sqlalchemy.org/en/13/orm/extensions/declarative/
#
# CLASSES
#     sqlalchemy.ext.declarative.api.Base(Base)
#         Archive
#         Document
#         Image
#         Observation
#         Platform
#         Tag
#
#     class Archive(sqlalchemy.ext.declarative.api.Base)
#      |  Archive(**kwargs)
#      |
#      |  Abstraction for archives as arbitrary collections of documents.
#      |
#      |  A good criteria for metadata providers (if determining "what archive does
#      |  this document belong to?" is not obvious) is to ask:
#      |
#      |      What *social* entity was responsible for this document for the greatest length of
#      |      time between the point (i) when meteorological data was observed and
# ...
